# %%
import os
import csv, subprocess
import pandas as pd

# %%
project = "PAS0654" #"PCON0003"
station = 2
year = 2013
isSim = 0
anaFolder = os.path.expanduser('/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/ARA_analysis/ARA_SourceSearch/')
step1_makePairs = anaFolder + "OSC_scripts/step1-make_ped_pairs/"
outputDir = "/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A%i/%i"%(station, year)

# %%
file = step1_makePairs+"A%i_%i_File_Ped_Pairs.txt"%(station,year)
print(file)
# Out:
# /users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/ARA_analysis/ARA_SourceSearch/OSC_scripts/step1-make_ped_pairs/A2_2013_File_Ped_Pairs.txt

# %%
with open(file, mode='r', newline='', encoding='utf-8-sig') as csvfile:
    reader = csv.reader(csvfile)
    for job in reader:
        split = os.path.split(job[0])
        run = os.path.splitext(split[1])[0].strip("event")
        dataFile = job[0]
        # else:
        #     dataFile =
        submit_command = ("sbatch "
                    "--job-name=makeSummary_{0}_{7} --output=./logs/{7}_makeSummary_{0}.out --account={6} "
                    "--export=ISSIM={1},STATION={2},DATA={3},PEDESTAL={4},OUTDIR={5} runOSC.sh").format(run,isSim,station,dataFile,job[1],outputDir, project, year)
        print(submit_command)

        # print("Submitted run%s"%run)
#         exit_status = subprocess.call(submit_command, shell=True)
#         if exit_status is 1:  # Check to make sure the job submitted
#             print("Job {0} failed to submit".format(submit_command))
        break
# Out:
# sbatch --job-name=makeSummary_002823_2014 --output=./logs/2014_makeSummary_002823.out --account=PAS0654 --export=ISSIM=0,STATION=2,DATA=/fs/scratch/PAS0654/jorge/ARA_data/10pct/A2/2014/0101/run002823/event002823.root,PEDESTAL=,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2014 runOSC.sh

# %%
job[0]
# Out:
# '/fs/scratch/PAS0654/jorge/ARA_data/10pct/A2/2013/run1449/event1449.root'

# %% [markdown]
# # Nested

# %%
cores = 6

# %%
count = 0
with open(file, mode='r', newline='', encoding='utf-8-sig') as csvfile:
    reader = csv.reader(csvfile)
    count_core = 0
    for job in reader:
        if(count_core==0):
            f = open("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/ARA_analysis/ARA_SourceSearch/OSC_scripts/step2-make_run_summary/tmpScipts/tmpSubmit_%i.sh"%count, "w+")
            f.write("#!/bin/bash\n\n")
            f.write("#SBATCH --mail-type=FAIL\n")
            f.write("#SBATCH --time=01:10:00\n\n")
            f.write("eval 'source /users/PCON0003/cond0068/.bash_profile_pitzer_cvmfs'\n")
            f.write("cd /users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/\n\n")
        dataFile = job[0]
        pedestal = job[1]
        f.write("./v2_analysis_run_summary ${ISSIM} ${STATION} ${OUTDIR} %s %s &\n"%(dataFile,pedestal))
        count_core+=1

        if(count_core==cores):
            f.write("wait\n")
            f.close()
            count+=1
            count_core = 0

        split = os.path.split(job[0])
        run = os.path.splitext(split[1])[0].strip("event")
        submit_command = ("sbatch "
                    "--job-name=makeSummary_{9}_{7} --nodes=1 --ntasks-per-node={8} --output=./logs/{7}_makeSummary_{0}.out --account={6} "
                    "--export=ISSIM={1},STATION={2},OUTDIR={5},YEAR={7} tmpScipts/tmpSubmit_{9}.sh").format(run,isSim,station,dataFile,job[1],outputDir, project, year, cores, count)
        print(submit_command)

        # print("Submitted run%s"%run)
#         exit_status = subprocess.call(submit_command, shell=True)
#         if exit_status is 1:  # Check to make sure the job submitted
#             print("Job {0} failed to submit".format(submit_command))
#         break
# Out:
# sbatch --job-name=makeSummary_1449_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1449.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_0.sh
# sbatch --job-name=makeSummary_1450_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1450.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_0.sh
# sbatch --job-name=makeSummary_1451_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1451.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_0.sh
# sbatch --job-name=makeSummary_1452_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1452.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_0.sh
# sbatch --job-name=makeSummary_1453_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1453.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_0.sh
# sbatch --job-name=makeSummary_1454_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1454.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1455_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1455.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1456_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1456.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1457_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1457.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1458_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1458.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1459_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1459.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_1.sh
# sbatch --job-name=makeSummary_1460_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1460.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1463_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1463.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1464_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1464.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1465_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1465.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1466_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1466.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1467_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1467.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_2.sh
# sbatch --job-name=makeSummary_1468_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1468.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1469_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1469.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1470_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1470.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1471_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1471.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1473_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1473.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1474_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1474.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_3.sh
# sbatch --job-name=makeSummary_1475_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1475.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1476_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1476.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1478_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1478.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1479_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1479.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1480_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1480.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1481_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1481.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_4.sh
# sbatch --job-name=makeSummary_1483_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1483.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1484_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1484.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1485_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1485.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1486_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1486.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1488_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1488.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1489_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1489.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_5.sh
# sbatch --job-name=makeSummary_1490_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1490.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1491_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1491.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1493_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1493.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1494_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1494.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1495_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1495.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1496_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1496.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_6.sh
# sbatch --job-name=makeSummary_1498_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1498.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1499_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1499.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1500_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1500.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1501_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1501.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1503_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1503.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1504_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1504.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_7.sh
# sbatch --job-name=makeSummary_1505_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1505.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1506_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1506.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1508_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1508.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1509_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1509.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1510_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1510.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1511_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1511.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_8.sh
# sbatch --job-name=makeSummary_1513_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1513.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1514_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1514.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1515_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1515.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1516_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1516.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1518_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1518.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1519_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1519.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_9.sh
# sbatch --job-name=makeSummary_1520_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1520.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1521_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1521.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1523_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1523.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1524_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1524.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1525_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1525.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1526_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1526.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_10.sh
# sbatch --job-name=makeSummary_1528_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1528.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1529_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1529.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1530_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1530.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1531_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1531.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1533_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1533.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1534_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1534.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_11.sh
# sbatch --job-name=makeSummary_1535_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1535.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1536_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1536.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1538_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1538.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1539_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1539.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1540_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1540.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1541_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1541.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_12.sh
# sbatch --job-name=makeSummary_1543_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1543.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1544_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1544.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1545_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1545.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1546_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1546.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1547_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1547.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1548_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1548.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_13.sh
# sbatch --job-name=makeSummary_1550_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1550.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1551_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1551.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1552_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1552.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1553_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1553.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1555_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1555.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1556_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1556.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_14.sh
# sbatch --job-name=makeSummary_1557_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1557.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1558_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1558.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1560_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1560.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1561_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1561.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1562_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1562.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1563_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1563.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_15.sh
# sbatch --job-name=makeSummary_1565_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1565.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1566_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1566.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1567_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1567.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1568_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1568.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1570_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1570.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1571_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1571.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_16.sh
# sbatch --job-name=makeSummary_1572_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1572.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1573_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1573.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1575_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1575.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1576_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1576.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1577_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1577.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1578_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1578.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_17.sh
# sbatch --job-name=makeSummary_1580_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1580.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1581_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1581.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1582_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1582.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1583_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1583.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1585_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1585.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1586_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1586.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_18.sh
# sbatch --job-name=makeSummary_1587_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1587.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1588_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1588.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1590_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1590.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1591_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1591.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1592_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1592.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1593_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1593.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_19.sh
# sbatch --job-name=makeSummary_1595_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1595.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1596_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1596.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1597_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1597.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1598_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1598.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1600_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1600.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1601_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1601.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_20.sh
# sbatch --job-name=makeSummary_1602_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1602.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1603_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1603.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1605_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1605.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1606_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1606.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1607_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1607.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1608_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1608.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_21.sh
# sbatch --job-name=makeSummary_1609_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1609.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1611_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1611.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1612_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1612.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1613_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1613.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1614_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1614.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1616_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1616.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_22.sh
# sbatch --job-name=makeSummary_1617_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1617.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1618_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1618.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1619_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1619.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1621_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1621.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1622_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1622.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1623_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1623.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_23.sh
# sbatch --job-name=makeSummary_1624_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1624.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1626_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1626.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1627_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1627.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1628_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1628.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1629_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1629.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1631_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1631.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_24.sh
# sbatch --job-name=makeSummary_1632_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1632.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1633_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1633.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1634_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1634.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1637_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1637.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1639_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1639.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1640_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1640.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_25.sh
# sbatch --job-name=makeSummary_1641_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1641.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1642_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1642.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1645_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1645.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1646_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1646.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1647_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1647.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1652_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1652.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_26.sh
# sbatch --job-name=makeSummary_1653_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1653.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1654_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1654.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1655_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1655.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1657_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1657.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1658_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1658.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1659_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1659.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_27.sh
# sbatch --job-name=makeSummary_1660_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1660.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1662_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1662.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1663_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1663.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1664_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1664.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1665_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1665.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1667_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1667.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_28.sh
# sbatch --job-name=makeSummary_1668_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1668.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_29.sh
# sbatch --job-name=makeSummary_1669_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1669.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_29.sh
# sbatch --job-name=makeSummary_1670_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1670.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_29.sh
# sbatch --job-name=makeSummary_1672_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1672.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_29.sh
# sbatch --job-name=makeSummary_1673_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_1673.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_29.sh
# ...
# sbatch --job-name=makeSummary_2718_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2718.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_149.sh
# sbatch --job-name=makeSummary_2719_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2719.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_149.sh
# sbatch --job-name=makeSummary_2721_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2721.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_149.sh
# sbatch --job-name=makeSummary_2723_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2723.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_149.sh
# sbatch --job-name=makeSummary_2724_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2724.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_149.sh
# sbatch --job-name=makeSummary_2725_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2725.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2726_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2726.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2727_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2727.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2729_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2729.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2730_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2730.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2731_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2731.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_150.sh
# sbatch --job-name=makeSummary_2732_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2732.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2734_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2734.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2735_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2735.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2736_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2736.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2737_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2737.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2739_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2739.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_151.sh
# sbatch --job-name=makeSummary_2740_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2740.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2741_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2741.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2742_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2742.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2744_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2744.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2745_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2745.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2746_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2746.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_152.sh
# sbatch --job-name=makeSummary_2747_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2747.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2749_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2749.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2750_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2750.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2751_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2751.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2752_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2752.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2754_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2754.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_153.sh
# sbatch --job-name=makeSummary_2755_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2755.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2756_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2756.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2757_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2757.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2759_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2759.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2760_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2760.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2762_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2762.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_154.sh
# sbatch --job-name=makeSummary_2763_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2763.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2764_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2764.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2765_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2765.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2768_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2768.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2769_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2769.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2770_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2770.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_155.sh
# sbatch --job-name=makeSummary_2771_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2771.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2772_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2772.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2774_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2774.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2775_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2775.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2776_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2776.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2777_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2777.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_156.sh
# sbatch --job-name=makeSummary_2779_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2779.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2780_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2780.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2781_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2781.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2782_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2782.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2784_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2784.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2785_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2785.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_157.sh
# sbatch --job-name=makeSummary_2786_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2786.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh
# sbatch --job-name=makeSummary_2787_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2787.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh
# sbatch --job-name=makeSummary_2789_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2789.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh
# sbatch --job-name=makeSummary_2790_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2790.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh
# sbatch --job-name=makeSummary_2791_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2791.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh
# sbatch --job-name=makeSummary_2792_2013 --nodes=1 --ntasks-per-node=6 --output=./logs/2013_makeSummary_2792.out --account=PAS0654 --export=ISSIM=0,STATION=2,OUTDIR=/fs/project/PAS0654/ARA_DATA/A23/10pctCalibBugFix/RunSummary/A2/2013,YEAR=2013 tmpScipts/tmpSubmit_158.sh

# %%
f = open("/users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/ARA_analysis/ARA_SourceSearch/OSC_scripts/step2-make_run_summary/tmpScipts/tmpSubmit_%i.sh"%count, "w+")
f.write("#!/bin/bash\n\n")
f.write("#SBATCH --mail-type=FAIL\n")
f.write("#SBATCH --time=01:10:00\n\n")
f.write("eval 'source /users/PCON0003/cond0068/.bash_profile_pitzer_cvmfs'\n")
f.write("cd /users/PAS0654/osu8354/ARA_cvmfs/source/AraRoot/analysis/")
f.write("./v2_analysis_run_summary ${ISSIM} ${STATION} ${OUTDIR} %s %s")
f.close()
