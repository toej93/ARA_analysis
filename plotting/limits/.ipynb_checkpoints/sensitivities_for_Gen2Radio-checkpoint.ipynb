# %%
from limits import LimitFigure, ara_energies, ara_available, ara_projected, ara_yearly, Gen2Year1
import importlib
import limits
import matplotlib as mpl
importlib.reload(limits)
import seaborn as sns
import numpy as np

# %%
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.unicode'] = True
mpl.rcParams['mathtext.rm'] = 'Times New Roman'
mpl.rcParams['mathtext.it'] = 'Times New Roman:italic'
mpl.rcParams['mathtext.bf'] = 'Times New Roman:bold'

mpl.rc('font', family='serif', size=12)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['ytick.major.size'] = 5

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
# mpl.rc('font', size=16)
mpl.rc('axes', titlesize=20)

current_palette = sns.color_palette('colorblind', 10)
# import warnings
# warnings.filterwarnings("ignore")

# %%
figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(0.5e-19, 2e-14), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])
# figure.build_base_plot('ara',models = ["Cuoco_CenA"])
figure.add_limit('ARA', ara_energies, ara_available+1*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='ARA SES limit')#Divide by 2.44 to get the SES
figure.add_limit('ARA', ara_energies, ara_available+2*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='')
figure.add_limit('ARA', ara_energies, ara_available+3*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='')
figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='')
# figure.show(legend_size=12, save_name='limit_CenA.png', dpi=200)


figure.add_limit('Gen2', ara_energies, Gen2Year1,
                stations=2.44, years=1, color='red', linestyle="-.",
                label='Gen2 Radio SES limit')#Divide by 2.44 to get the SES
figure.show(legend_size=15)#, save_name='limits_plot_AmySnowmass.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac14379c2b0> has a label of '_line5' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac14598ad68> has a label of '_line6' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac145994898> has a label of '_line7' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %% [markdown]
#   # Neutrinos per year

# %%
import matplotlib.pyplot as plt

# %%
data_ara_200 = {
    "pyrex": {
        "energy": 10**np.array([16.0, 16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0]) / 1e9,
        "veff": np.array([7.753e-03, 6.872e-02, 4.235339e-01, 1.646e+00, 5.110e+00,
                          1.106e+01, 2.053e+01, 34.070, 51.321])
    },
    "arasim": {
        "energy": 10**np.array([16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0]) / 1e9,
        "veff": np.array([1.105E-1, 5.195E-1, 1.826E+0, 5.259E+0,
                          1.106E+1, 2.077E+1, 3.431E+1, 5.073E+1])
    }
}

Gen2_deep = {
    "pyrex": {
        "energy": 10**np.array([15.5, 16.0, 16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0]) / 1e9,
        "veff": np.array([2.877540e-04, 5.162349e-03, 8.974606e-02, 7.046026e-01, 3.240527e+00,
                          9.073894e+00, 1.794062e+01, 2.786132e+01, 3.692925e+01, 4.513341e+01])
    },
    "arasim": {
        "energy": 10**np.array([16.5, 17.0, 17.5, 18.0, 18.5, 19.0, 19.5, 20.0]) / 1e9,
        "veff": np.array([1.453E-1, 5.370E-1, 1.665E+0, 4.151E+0,
                          8.062E+0, 1.303E+1, 1.960E+1, 2.758E+1])
    }
}

# %%
plt.loglog(data_ara_200["pyrex"]["energy"], data_ara_200["pyrex"]["veff"], label = "A2")
plt.loglog(Gen2_deep["pyrex"]["energy"], Gen2_deep["pyrex"]["veff"], label = "Gen2 Deep")
plt.legend()
