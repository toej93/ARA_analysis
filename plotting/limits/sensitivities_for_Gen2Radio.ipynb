# %%
from limits import LimitFigure, ara_energies, ara_available, ara_projected, ara_yearly, Gen2Year1, Gen2Year2, Gen2Year3, Gen2Year4, Gen2Year5, Gen2Year6, Gen2Year7
import importlib
import limits
import matplotlib as mpl
importlib.reload(limits)
import seaborn as sns
import numpy as np

# %%
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.unicode'] = True
mpl.rcParams['mathtext.rm'] = 'Times New Roman'
mpl.rcParams['mathtext.it'] = 'Times New Roman:italic'
mpl.rcParams['mathtext.bf'] = 'Times New Roman:bold'

mpl.rc('font', family='serif', size=12)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['ytick.major.size'] = 5

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
# mpl.rc('font', size=16)
mpl.rc('axes', titlesize=20)

current_palette = sns.color_palette('colorblind', 10)
# import warnings
# warnings.filterwarnings("ignore")

# %%
figure = LimitFigure(e_power=1, xlims=(1e6, 1e11), ylims=(0.5e-20, 2e-14), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])
figure.add_limit('ARA', ara_energies, ara_available+1*ara_yearly,
                stations=1, years=1, color='black', linestyle="dotted",
                label='ARA projected limit (2023)')#Divide by 2.44 to get the SES
# figure.add_limit('ARA', ara_energies, ara_available+2*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='')
# figure.add_limit('ARA', ara_energies, ara_available+3*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='')
# figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='')
# figure.show(legend_size=12, save_name='limit_CenA.png', dpi=200)


figure.add_limit('Gen2', ara_energies, Gen2Year1,
                stations=1, years=1, color='red', linestyle="-",
                label='Gen2-Radio projected limit (years 1-7)')#Divide by 2.44 to get the SES
figure.add_limit('Gen2', ara_energies, Gen2Year2,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year3,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year4,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year5,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year6,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year7,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.show(legend_size=15)#, save_name='limits_plot_AmySnowmass.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac1464d71d0> has a label of '_line6' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac1464d7cc0> has a label of '_line7' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac1464d7fd0> has a label of '_line8' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# ...

# %% [markdown]
#   # $E^2$

# %%
figure = LimitFigure(e_power=2, xlims=(1e6, 1e11), ylims=(0.5e-11, 1e-6), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])
# figure.build_base_plot('ara',models = ["Cuoco_CenA"])
# figure.add_limit('ARA', ara_energies, ara_available+1*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='ARA SES')#Divide by 2.44 to get the SES
# figure.add_limit('ARA', ara_energies, ara_available+2*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='')
# figure.add_limit('ARA', ara_energies, ara_available+3*ara_yearly,
#                 stations=1, years=1, color='black', linestyle="dotted",
#                 label='')
figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
                stations=1, years=1, color='black', linestyle="dotted",
                label='ARA projected limit (2023)')
# figure.show(legend_size=12, save_name='limit_CenA.png', dpi=200)


figure.add_limit('Gen2', ara_energies, Gen2Year1,
                stations=1, years=1, color='red', linestyle="-",
                label='Gen2 Radio projected limit (years 1-7)')#Divide by 2.44 to get the SES
figure.add_limit('Gen2', ara_energies, Gen2Year2,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year3,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year4,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year5,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year6,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year7,
                stations=1, years=1, color='red', linestyle="-",
                label='')
figure.show(legend_size=15)#, save_name='limits_plot_AmySnowmass.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac146642470> has a label of '_line6' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac1466429e8> has a label of '_line7' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2ac1466abb00> has a label of '_line8' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# ...
