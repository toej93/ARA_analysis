# %%
from limits import LimitFigure, ara_energies, ara_available, ara_projected, ara_yearly, Gen2Year1, Gen2Year2, Gen2Year3, Gen2Year4, Gen2Year5, Gen2Year6, Gen2Year7, Gen2Year10
import importlib
import limits
import matplotlib as mpl
importlib.reload(limits)
import seaborn as sns
import numpy as np

# %%
mpl.rcParams['text.usetex'] = True
mpl.rcParams['text.latex.unicode'] = True
mpl.rcParams['mathtext.rm'] = 'Times New Roman'
mpl.rcParams['mathtext.it'] = 'Times New Roman:italic'
mpl.rcParams['mathtext.bf'] = 'Times New Roman:bold'

mpl.rc('font', family='serif', size=12)
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['ytick.major.size'] = 5

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
# mpl.rc('font', size=16)
mpl.rc('axes', titlesize=20)

current_palette = sns.color_palette('colorblind', 10)
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
#   # $E^2$

# %%
figure = LimitFigure(e_power=2, xlims=(1e6, 1e11), ylims=(0.5e-11, 1e-4), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])

# figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='ARA SES (2023)')

figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='_nolegend_')
pal4 = ['black','#b10026','#e31a1c','#fc4e2a','#fd8d3c','#feb24c','#feb28c']
# figure.add_limit('Gen2', ara_energies, Gen2Year1,
#                 stations=2.44, years=0.5, color=pal4[6], linestyle="-",
#                 label='Gen2 Radio SES (years 1-7, 50\% uptime)')#Divide by 2.44 to get the SES
# figure.add_limit('Gen2', ara_energies, Gen2Year2,
#                 stations=2.44, years=0.5, color=pal4[5], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year3,
#                 stations=2.44, years=0.5, color=pal4[4], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year4,
#                 stations=2.44, years=0.5, color=pal4[3], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year5,
#                 stations=2.44, years=0.5, color=pal4[2], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year6,
#                 stations=2.44, years=0.5, color=pal4[1], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year7,
#                 stations=2.44, years=0.5, color=pal4[0], linestyle="-",
#                 label='')
# figure.add_limit('Gen2', ara_energies, Gen2Year10,
#                 stations=2.44, years=0.5, color='purple', linestyle="-",
#                 label='Gen2 Radio SES (year 10)')
figure.show(legend_size=12, save_name='limits_plot_ARA_E2.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b83970048> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %% [markdown]
# # 100% uptime

# %%
figure = LimitFigure(e_power=2, xlims=(1e6, 1e11), ylims=(0.5e-11, 1e-4), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])

figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='_nolegend_')
pal4 = ['black','#b10026','#e31a1c','#fc4e2a','#fd8d3c','#feb24c','#feb28c']
figure.add_limit('Gen2', ara_energies, Gen2Year1,
                stations=2.44, years=1, color=pal4[6], linestyle="-",
                label='Gen2 Radio SES (years 1-7, 100\% uptime)')#Divide by 2.44 to get the SES
figure.add_limit('Gen2', ara_energies, Gen2Year2,
                stations=2.44, years=1, color=pal4[5], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year3,
                stations=2.44, years=1, color=pal4[4], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year4,
                stations=2.44, years=1, color=pal4[3], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year5,
                stations=2.44, years=1, color=pal4[2], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year6,
                stations=2.44, years=1, color=pal4[1], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year7,
                stations=2.44, years=1, color=pal4[0], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year10,
                stations=2.44, years=1, color='purple', linestyle="-",
                label='Gen2 Radio SES (year 10, 100\% uptime)')
figure.show(legend_size=12, save_name='limits_plot_ARA_Gen2_E2.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b84a13198> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b842c40b8> has a label of '_line10' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b830d0828> has a label of '_line11' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# ...

# %% [markdown]
# # 50% Uptime

# %%
figure = LimitFigure(e_power=2, xlims=(1e6, 1e11), ylims=(0.5e-11, 1e-4), font_size=16, tick_size=14)
figure.build_base_plot('ara_Gen2',models = ['ahlers_1', "murase_grb"])

# figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
#                 stations=2.44, years=1, color='black', linestyle="dotted",
#                 label='ARA SES (2023)')

figure.add_limit('ARA', ara_energies, ara_available+4*ara_yearly,
                stations=2.44, years=1, color='black', linestyle="dotted",
                label='_nolegend_')
pal4 = ['black','#b10026','#e31a1c','#fc4e2a','#fd8d3c','#feb24c','#feb28c']
figure.add_limit('Gen2', ara_energies, Gen2Year1,
                stations=2.44, years=0.5, color=pal4[6], linestyle="-",
                label='Gen2 Radio SES (years 1-7, 50\% uptime)')#Divide by 2.44 to get the SES
figure.add_limit('Gen2', ara_energies, Gen2Year2,
                stations=2.44, years=0.5, color=pal4[5], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year3,
                stations=2.44, years=0.5, color=pal4[4], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year4,
                stations=2.44, years=0.5, color=pal4[3], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year5,
                stations=2.44, years=0.5, color=pal4[2], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year6,
                stations=2.44, years=0.5, color=pal4[1], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year7,
                stations=2.44, years=0.5, color=pal4[0], linestyle="-",
                label='')
figure.add_limit('Gen2', ara_energies, Gen2Year10,
                stations=2.44, years=0.5, color='purple', linestyle="-",
                label='Gen2 Radio SES (year 10, 50\% uptime), ')
figure.show(legend_size=12, save_name='limits_plot_ARA_Gen2_E2_50PercentUptime.pdf')
# Out:
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b80cc5cf8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b83e9cda0> has a label of '_line10' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# /usr/local/python/3.6-conda5.2/lib/python3.6/site-packages/matplotlib/legend.py:593: UserWarning: The handle <matplotlib.lines.Line2D object at 0x2b4b8300c710> has a label of '_line11' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))
# ...
