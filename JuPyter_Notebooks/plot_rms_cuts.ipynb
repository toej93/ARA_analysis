# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c1 = pd.read_csv("wfront_RMS_cut_A3_c1.csv")

# %%
c1
# Out:
#     cut    vpol    hpol     all
# 0  -1.2   4.745  15.004  17.419
# 1  -1.1   6.181  17.806  20.576
# 2  -1.4   2.543   9.676  11.330
# 3  -1.5   1.772   7.296   8.584
# 4  -1.3   3.542  12.276  14.319
# 5  -0.7  14.002  28.774  32.826
# 6  -0.6  16.227  31.223  35.580
# 7  -1.0   7.853  20.657  23.765
# 8  -0.9   9.742  23.457  26.889
# 9  -0.8  11.819  26.176  29.919
# 10 -0.5  18.398  33.461  38.123

# %%
plt.scatter(c1["cut"],c1["all"], label="all")
plt.scatter(c1["cut"],c1["vpol"],label="vpol")
plt.scatter(c1["cut"],c1["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C1, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.ylim(0,50)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A3_c1.png", dpi=200)

# %%
c2 = pd.read_csv("wfront_RMS_cut_A3_c2.csv")
plt.scatter(c2["cut"],c2["all"], label="all")
plt.scatter(c2["cut"],c2["vpol"],label="vpol")
plt.scatter(c2["cut"],c2["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C2, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.ylim(0,50)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A3_c2.png", dpi=200)

# %%
c3 = pd.read_csv("wfront_RMS_cut_A3_c3.csv")
plt.scatter(c3["cut"],c3["all"], label="all")
plt.scatter(c3["cut"],c3["vpol"],label="vpol")
plt.scatter(c3["cut"],c3["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C3, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.ylim(0,50)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A3_c3.png", dpi=200)

# %%
c4 = pd.read_csv("wfront_RMS_cut_A3_c4.csv")
plt.scatter(c4["cut"],c4["all"], label="all")
plt.scatter(c4["cut"],c4["vpol"],label="vpol")
plt.scatter(c4["cut"],c4["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C4, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.ylim(0,50)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A3_c4.png", dpi=200)

# %%
c5 = pd.read_csv("wfront_RMS_cut_A3_c5.csv")
plt.scatter(c5["cut"],c5["all"], label="all")
plt.scatter(c5["cut"],c5["vpol"],label="vpol")
plt.scatter(c5["cut"],c5["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C5, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.ylim(0,50)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A3_c5.png", dpi=200)

# %%
c1_sim = pd.read_csv("wfront_RMS_cut_c1_sim.csv")
plt.scatter(c1_sim["cut"],c1_sim["all"], label="all")
plt.scatter(c1_sim["cut"],c1_sim["vpol"],label="vpol")
plt.scatter(c1_sim["cut"],c1_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C1, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_c1_sim.png", dpi=200)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-796303dd4326> in <module>()
# ----> 1 c1_sim = pd.read_csv("wfront_RMS_cut_c1_sim.csv")
#       2 plt.scatter(c1_sim["cut"],c1_sim["all"], label="all")
#       3 plt.scatter(c1_sim["cut"],c1_sim["vpol"],label="vpol")
#       4 plt.scatter(c1_sim["cut"],c1_sim["hpol"],label="hpol")
#       5
#
# ...

# %%
c2_sim = pd.read_csv("wfront_RMS_cut_c2_sim.csv")
plt.scatter(c2_sim["cut"],c2_sim["all"], label="all")
plt.scatter(c2_sim["cut"],c2_sim["vpol"],label="vpol")
plt.scatter(c2_sim["cut"],c2_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C2, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_c2_sim.png", dpi=200)

# %%
c3_sim = pd.read_csv("wfront_RMS_cut_c3_sim.csv")
plt.scatter(c3_sim["cut"],c3_sim["all"], label="all")
plt.scatter(c3_sim["cut"],c3_sim["vpol"],label="vpol")
plt.scatter(c3_sim["cut"],c3_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C3, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_c3_sim.png", dpi=200)

# %%
c4_sim = pd.read_csv("wfront_RMS_cut_c4_sim.csv")
plt.scatter(c4_sim["cut"],c4_sim["all"], label="all")
plt.scatter(c4_sim["cut"],c4_sim["vpol"],label="vpol")
plt.scatter(c4_sim["cut"],c4_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("C4, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_c4_sim.png", dpi=200)

# %% [markdown]
# # A2

# %%
c1 = pd.read_csv("wfront_RMS_cut_A2_c1.csv")
plt.scatter(c1["cut"],c1["all"], label="all")
plt.scatter(c1["cut"],c1["vpol"],label="vpol")
plt.scatter(c1["cut"],c1["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c1, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c1_data.png", dpi=200)

# %%
c2 = pd.read_csv("wfront_RMS_cut_A2_c2.csv")
plt.scatter(c2["cut"],c2["all"], label="all")
plt.scatter(c2["cut"],c2["vpol"],label="vpol")
plt.scatter(c2["cut"],c2["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c2, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c2_data.png", dpi=200)

# %%
c3 = pd.read_csv("wfront_RMS_cut_A2_c3.csv")
plt.scatter(c3["cut"],c3["all"], label="all")
plt.scatter(c3["cut"],c3["vpol"],label="vpol")
plt.scatter(c3["cut"],c3["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c3, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c3_data.png", dpi=200)

# %%
c4 = pd.read_csv("wfront_RMS_cut_A2_c4.csv")
plt.scatter(c4["cut"],c4["all"], label="all")
plt.scatter(c4["cut"],c4["vpol"],label="vpol")
plt.scatter(c4["cut"],c4["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c4, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c4_data.png", dpi=200)

# %%
c5 = pd.read_csv("wfront_RMS_cut_A2_c5.csv")
plt.scatter(c5["cut"],c5["all"], label="all")
plt.scatter(c5["cut"],c5["vpol"],label="vpol")
plt.scatter(c5["cut"],c5["hpol"],label="hpol")
plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c5, data", fontsize=15)
plt.axhline(y=10,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c5_data.png", dpi=200)

# %% [markdown]
# ## Sim

# %%
c1_sim = pd.read_csv("wfront_RMS_cut_A2_c1_sim.csv")
plt.scatter(c1_sim["cut"],c1_sim["all"], label="all")
plt.scatter(c1_sim["cut"],c1_sim["vpol"],label="vpol")
plt.scatter(c1_sim["cut"],c1_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c1, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c1_sim.png", dpi=200)

# %%
c2_sim = pd.read_csv("wfront_RMS_cut_A2_c2_sim.csv")
plt.scatter(c2_sim["cut"],c2_sim["all"], label="all")
plt.scatter(c2_sim["cut"],c2_sim["vpol"],label="vpol")
plt.scatter(c2_sim["cut"],c2_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c2, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c2_sim.png", dpi=200)

# %%
c3_sim = pd.read_csv("wfront_RMS_cut_A2_c3_sim.csv")
plt.scatter(c3_sim["cut"],c3_sim["all"], label="all")
plt.scatter(c3_sim["cut"],c3_sim["vpol"],label="vpol")
plt.scatter(c3_sim["cut"],c3_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c3, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c3_sim.png", dpi=200)

# %%
c4_sim = pd.read_csv("wfront_RMS_cut_A2_c4_sim.csv")
plt.scatter(c4_sim["cut"],c4_sim["all"], label="all")
plt.scatter(c4_sim["cut"],c4_sim["vpol"],label="vpol")
plt.scatter(c4_sim["cut"],c4_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c4, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c4_sim.png", dpi=200)

# %%
c5_sim = pd.read_csv("wfront_RMS_cut_A2_c5_sim.csv")
plt.scatter(c5_sim["cut"],c5_sim["all"], label="all")
plt.scatter(c5_sim["cut"],c5_sim["vpol"],label="vpol")
plt.scatter(c5_sim["cut"],c5_sim["hpol"],label="hpol")

plt.legend()
plt.xlabel("Wavefront RMS cut value [$\log_{10}$(RMS)]", fontsize=13)
plt.ylabel("Rate of passed events [%]",fontsize=13)
plt.title("A2/c5, sim", fontsize=15)
plt.axhline(y=90,color="red", ls="--", alpha=0.5)
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/wfront_RMS_cut_A2_c5_sim.png", dpi=200)

# %% [markdown]
# # CW

# %%
import numpy as np

# %%
CW = pd.read_csv("CWID_A3_c5.csv")
CW = CW.sort_values(by=['run'])
calpul = pd.read_csv("./a23_analysis_tools/data/A3_c5_untagged_calpul.csv")
calpul = calpul.sort_values(by=['Run Number'])

plt.plot(CW["run"],CW["phase_var"],label="Phase variance",linewidth=1,alpha=0.9)
plt.plot(CW["run"],CW["baseline"],"--",label="Peaks over baselines",linewidth=1,alpha=0.9)
plt.scatter(calpul["Run Number"],0*calpul["Ratio"],label="Untagged calpusers",marker="s",s=40,alpha=1,color="red")
plt.title("Events tagged by the CW phase variance method, A3/c5", fontsize=14)
plt.xlabel("Run Number",fontsize=13)
plt.ylabel("Contaminated events [%]",fontsize=13)
# plt.xlim(1450,1910)
plt.ylim(0,100)
plt.legend(loc='best')
plt.tight_layout()
plt.savefig("/users/PCON0003/cond0068/ARA/CWID_A3_c5_var_baselines.png", dpi=200)

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Run Number',fontsize=13)
ax1.set_ylabel('exp', color=color)
ax1.plot(CW["run"],CW["phase_var"],label="Phase variance",linewidth=1,color=color)
ax1.plot(CW["run"],CW["baseline"],"--",label="Peaks over baselines",linewidth=1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('#calpulsers/#events', color=color,fontsize=13)  # we already handled the x-label with ax1
ax2.plot(calpul["Run Number"],0*calpul["Ratio"],label="Peaks over baselines",linewidth=1,color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.xlim(1450,1910)

fig.tight_layout()  # otherwise the right y-label is slightly clipped

# %%
#colnames=['mean_ch0', 'Veff', 'Err'] 
#data = pd.read_csv("/users/PAS0654/osu8354/ARA/AraSim/AraSim_versions/ARA02_type_1/Veff_config1.csv", names=colnames, header=None)
colnames={}
colnames["runNum"]="runNum"
for x in range(1,32,2):
        colnames["mean_ch{0}".format(int(x/2))]="mean_ch{0}".format(int(x/2))
        colnames["std_ch{0}".format(int(x/2))]="std_ch{0}".format(int(x/2))

# %%
rms=pd.read_csv("rms_A3_c5.txt", names=colnames, header=None, )
rms = rms.sort_values(by=['runNum'])
rms.head()
# Out:
#     runNum  mean_ch0  std_ch0  mean_ch1  std_ch1  mean_ch2  std_ch2  mean_ch3  \
# 3     1922     29.38     9.96     39.18    20.45     24.20     9.41     22.56
# 4     1924     29.16     9.63     38.77    19.98     23.78     8.00     22.33
# 15    1925     29.33     9.59     38.69    19.82     21.16     2.32     22.34
# 12    1926     29.28     9.50     38.75    20.00     23.68     7.93     22.35
# 13    1929     29.40     9.71     38.53    19.68     21.14     2.32     22.30
#
#     std_ch3  mean_ch4    ...     mean_ch11  std_ch11  mean_ch12  std_ch12  \
# 3      7.85     26.96    ...          8.74      1.05      15.14      1.82
# 4      7.49     26.86    ...          8.75      1.05      15.08      1.82
# 15     7.59     26.98    ...          8.73      1.03      15.03      1.79
# 12     7.70     26.93    ...          8.74      1.06      15.04      1.80
# 13     7.58     27.08    ...          8.72      1.05      15.08      1.81
#
# ...

# %%
#Need to create dictionaries
mean={}
for x in range(0,16):
        mean[x]="mean_ch{0}".format(x)
std={}
for x in range(0,10,2):
        std[x]="std_ch{0}".format(x)

# %%
rms=pd.read_csv("rms_A3_c2.txt", names=colnames, header=None, )
rms = rms.sort_values(by=['runNum'])
rms.head()


fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.suptitle('Average RMS per run, A3/c2')

for x in range(0,16,4):
    ax1.plot(rms["runNum"],rms["mean_ch{0}".format(x)],label="ch{0}".format(x))
ax1.legend(loc="upper left")
ax1.set_ylim(5,70)
ax1.set_ylabel("Avg rms [mV]")

for x in range(1,15,4):
    ax2.plot(rms["runNum"],rms["mean_ch{0}".format(x)],label="ch{0}".format(x))
ax2.legend(loc="upper left")
ax2.set_ylim(5,70)

for x in range(2,16,4):
    ax3.plot(rms["runNum"],rms["mean_ch{0}".format(x)],label="ch{0}".format(x))
ax3.legend(loc="upper left")
ax3.set_ylim(5,70)
ax3.set_ylabel("Avg rms [mV]")
ax3.set_xlabel("Run Number")


for x in range(3,16,4):
    ax4.plot(rms["runNum"],rms["mean_ch{0}".format(x)],label="ch{0}".format(x))
ax4.legend(loc="upper left")
ax4.set_xlabel("Run Number")
ax4.set_ylim(5,70)

# for ax in fig.get_axes():
#     ax.label_outer()
# fig.tight_layout()
fig.savefig("/users/PCON0003/cond0068/ARA/RMS_c2.png", dpi=200)
